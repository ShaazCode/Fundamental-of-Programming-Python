# %% [markdown]
# <a href="https://colab.research.google.com/github/ShaazCode/Fundamental-of-Programming-Python/blob/main/Config.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# For connecting the google colab code with github we have to follow this steps

# %%
from google.colab import auth
auth.authenticate_user()

# %%
# !git config --global user.name "ShaazCode"

# %%
# !git config --global user.email "shaaz.code@gmail.com"

# %%
# !git clone https://github.com/ShaazCode/new.git
# Out:
# fatal: destination path 'new' already exists and is not an empty directory.

# %%
print("Hello World")
# Out:
# Hello World

# %%
# after follwoing this step at the end go to files -> save a copy in github
# and select the particular repo where you want to push the code
